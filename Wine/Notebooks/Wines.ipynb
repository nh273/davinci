# %%
import nltk
import pandas as pd
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import bokeh
import matplotlib.pyplot as plt
import pylab as pl
from ast import literal_eval
import string
import random
import cache_magic
from scipy.cluster.hierarchy import linkage, dendrogram, to_tree
from sklearn.metrics.pairwise import cosine_similarity
import re
from nltk.stem import WordNetLemmatizer

# %%
import os

# %%
DATA_MAG = "/Users/pnguyen/Documents/DaVinci/Data/wine-reviews/winemag-data-130k-v2.csv"

# %%
TOKENIZED_DATA_MAG = "/Users/pnguyen/Documents/DaVinci/Data/wine-reviews/winemag-data-130k-v2-tokenized.csv"

# %%
df = pd.read_csv(DATA_MAG, index_col=0)
df.shape
# Out:
# (129971, 13)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (119988, 13)

# %%
df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119988 entries, 0 to 129970
# Data columns (total 13 columns):
# country                  119929 non-null object
# description              119988 non-null object
# designation              85443 non-null object
# points                   119988 non-null int64
# price                    111593 non-null float64
# province                 119929 non-null object
# region_1                 100428 non-null object
# region_2                 46769 non-null object
# taster_name              95071 non-null object
# taster_twitter_handle    90542 non-null object
# title                    119988 non-null object
# variety                  119987 non-null object
# winery                   119988 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 12.8+ MB

# %%
df.rename(columns={'variety': 'varietal'}, inplace=True)
# gotta use the correct terminology
# yes I'm a bit snobbish why'd you ask?
# sorry not sorry

# %%
df.hist(column = 'price', bins=100, log=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a22576f28>]],
#       dtype=object)

# %%
df.hist(column = 'points', bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a20b49ba8>]],
#       dtype=object)

# %%
df['unique_taster'] = df['taster_name'] + df['taster_twitter_handle'].fillna('__notwitter')

# %%
df['unique_taster'].value_counts()
# Out:
# Roger Voss@vossroger                23560
# Michael Schachner@wineschach        14046
# Kerin O’Keefe@kerinokeefe            9697
# Paul Gregutt@paulgwine               8868
# Virginie Boone@vboone                8708
# Matt Kettmann@mattkettmann           5730
# Joe Czerwinski@JoeCz                 4766
# Sean P. Sullivan@wawinereport        4461
# Anna Lee C. Iijima__notwitter        4017
# Jim Gordon@gordone_cellars           3766
# Anne Krebiehl MW@AnneInVino          3290
# Lauren Buzzeo@laurbuzz               1700
# Susan Kostrzewa@suskostrzewa         1023
# Mike DeSimone@worldwineguys           461
# Jeff Jenssen@worldwineguys            436
# Alexander Peartree__notwitter         383
# Carrie Dykes__notwitter               129
# Fiona Adams@bkfiona                    24
# Christina Pickard@winewchristina        6
# Name: unique_taster, dtype: int64

# %%
fig, ax = plt.subplots()
df['country'].value_counts().plot(ax=ax, kind='bar')

# %% [markdown]
# A few countries makes up for most of the wines

# %%
df.groupby(by='province')['title'].nunique().hist(bins=100)
df.groupby(by='province')['title'].nunique().mean() #number of wines per province on average
# Out:
# 279.48470588235296

# %%
df['province'].value_counts()[:10]
# Out:
# California          33656
# Washington           7965
# Bordeaux             5556
# Tuscany              5391
# Oregon               4929
# Burgundy             3683
# Northern Spain       3554
# Piedmont             3441
# Mendoza Province     3038
# Veneto               2501
# Name: province, dtype: int64

# %%
df['varietal'].value_counts()[:50]
# Out:
# Pinot Noir                       12278
# Chardonnay                       10868
# Cabernet Sauvignon                8840
# Red Blend                         8243
# Bordeaux-style Red Blend          6471
# Riesling                          4773
# Sauvignon Blanc                   4575
# Syrah                             3828
# Rosé                              3220
# Merlot                            2896
# Nebbiolo                          2607
# Zinfandel                         2530
# Sangiovese                        2462
# Malbec                            2446
# Portuguese Red                    2282
# White Blend                       2179
# Sparkling Blend                   1971
# Tempranillo                       1671
# Rhône-style Red Blend             1343
# Pinot Gris                        1324
# Champagne Blend                   1308
# Cabernet Franc                    1243
# Grüner Veltliner                  1201
# Portuguese White                  1057
# Bordeaux-style White Blend         993
# Pinot Grigio                       980
# Gewürztraminer                     940
# Gamay                              926
# Viognier                           922
# Shiraz                             790
# Petite Sirah                       702
# Sangiovese Grosso                  696
# Glera                              646
# Barbera                            644
# Port                               628
# Grenache                           607
# Corvina, Rondinella, Molinara      574
# Tempranillo Blend                  553
# Chenin Blanc                       546
# Carmenère                          533
# Albariño                           434
# Rhône-style White Blend            395
# Pinot Blanc                        395
# Aglianico                          339
# Moscato                            330
# Nero d'Avola                       324
# Garnacha                           308
# Sauvignon                          282
# Verdejo                            266
# Melon                              256
# Name: varietal, dtype: int64

# %% [markdown]
# Uh-oh. Looks like there are 2 big confusions: 'Syrah' & 'Shiraz' are the same grape. Something called 'Sauvignon', which should really be 'Sauvignon Blanc'. Let's just check to be sure that it's not 'Sauvignon Vert' or sth.

# %%
df[df['varietal']=='Sauvignon']['province'].value_counts()
# Out:
# Northeastern Italy      252
# Northern Spain            5
# Veneto                    3
# Sicily & Sardinia         3
# Central Italy             3
# Südsteiermark             2
# Piedmont                  2
# Bordeaux                  1
# Tuscany                   1
# Štajerska                 1
# Vipavska Dolina           1
# Victoria                  1
# Languedoc-Roussillon      1
# Tikves                    1
# Dealu Mare                1
# Loire Valley              1
# Brda                      1
# Southern Italy            1
# Marlborough               1
# Name: province, dtype: int64

# %%
df[df['varietal']=='Sauvignon']['taster_name'].value_counts()
# Out:
# Kerin O’Keefe         165
# Michael Schachner       5
# Anne Krebiehl MW        2
# Anna Lee C. Iijima      2
# Jeff Jenssen            2
# Roger Voss              2
# Joe Czerwinski          2
# Susan Kostrzewa         1
# Name: taster_name, dtype: int64

# %%
df[(df['varietal']=='Sauvignon') & (df['taster_name']=="Kerin O’Keefe")][['title','description']]
# Out:
#                                                     title  \
# 650                         Sturm 2014 Sauvignon (Collio)
# 1292                     Cembra 2013 Sauvignon (Trentino)
# 1399                  Caldaro 2014 Sauvignon (Alto Adige)
# 1403    Manincor 2014 Tannenberg Sauvignon (Alto Adige...
# 1408            Nals Margreid 2014 Sauvignon (Alto Adige)
# 2725    MandraRossa 2015 Urra di Mare Sauvignon (Sicilia)
# 3905              Ronco dei Tassi 2014 Sauvignon (Collio)
# 3911    La Vis 2014 Vigna Maso Tratta Sauvignon (Trent...
# 6259        St. Pauls 2013 Passion Sauvignon (Alto Adige)
# 6885                   Ca'Ronesca 2014 Sauvignon (Collio)
# 6887    Castello di Buttrio 2014 Sauvignon (Friuli Col...
# 6893       Erste Neue 2014 Classic Sauvignon (Alto Adige)
# 6906     Petrucco 2014 Sauvignon (Friuli Colli Orientali)
# 6936             Russiz Superiore 2013 Sauvignon (Collio)
# 9042    Niedermayr Josef 2012 Naun Sauvignon (Alto Adige)
# 11725          Weingut Niklas 2012 Sauvignon (Alto Adige)
# 12116             Ronco dei Tassi 2015 Sauvignon (Collio)
# 12387   Kellerei Kaltern Caldaro 2011 Castel Giovanell...
# 12641             Jermann 2015 Sauvignon (Venezia Giulia)
# 12735    Masut da Rive 2013 Sauvignon (Isonzo del Friuli)
# 14373   Vie di Romans 2015 Vieris Sauvignon (Friuli Is...
# 14778   Elena Walch 2015 Castel Ringberg Sauvignon (Al...
# 14793       St. Pauls 2015 Passion Sauvignon (Alto Adige)
# 14883                   La Rajade 2015 Sauvignon (Collio)
# 16163     Villa Russiz 2015 De La Tour Sauvignon (Collio)
# 16722                        Castelvecchio 2015 Sauvignon
# 17323               Gradis'ciutta 2013 Sauvignon (Collio)
# 17657   Tenuta Cà Bolani 2013 Aquilis Sauvignon (Friul...
# 18401   La Tunella 2013 Sauvignon (Colli Orientali del...
# 19315            Russiz Superiore 2012 Sauvignon (Collio)
# ...                                                   ...
# 103025               Villa Russiz 2015 Sauvignon (Collio)
# 103046  Tiefenbrunner 2012 Kirchleiten Sauvignon (Alto...
# 103443                 Tramin 2014 Sauvignon (Alto Adige)
# 103448                Kössler 2014 Sauvignon (Alto Adige)
# 103461   Cantina Valle Isarco 2014 Sauvignon (Alto Adige)
# 103472  Falkenstein 2013 Val Venosta Sauvignon (Alto A...
# 110359  Tiefenbrunner 2014 Rachtl Riserva Sauvignon (A...
# 110560     Conte Leopardi 2012 Calcare Sauvignon (Marche)
# 110915         Castello di Spessa 2015 Sauvignon (Collio)
# 111230  Nals Margreid 2012 Mantele Sauvignon (Alto Adige)
# 112944         Colmello di Grotta 2015 Sauvignon (Collio)
# 116080       Erste Neue 2012 Stern Sauvignon (Alto Adige)
# 118098           Terlan 2015 Winkl Sauvignon (Alto Adige)
# 118130             Attems 2015 Cicinis Sauvignon (Collio)
# 118326  Manincor 2012 Tannenberg Sauvignon (Alto Adige...
# 119100  Vie di Romans 2012 Vieris Sauvignon (Friuli Is...
# 119494  Vie di Romans 2011 Vieris Sauvignon (Friuli Is...
# 120464    Comelli 2014 Sauvignon (Friuli Colli Orientali)
# 120475      Valle 2014 Sauvignon (Friuli Colli Orientali)
# 120841    Tenuta Luisa 2016 Sauvignon (Isonzo del Friuli)
# 121998                      Fiegl 2014 Sauvignon (Collio)
# 122001     Caldaro 2014 Plemstaler Sauvignon (Alto Adige)
# 123001  Piera Martellozzo 2012 Sauvignon Terre Magre S...
# 124865  Venica & Venica 2015 Ronco del Cerò Sauvignon ...
# 124878                      Muzic 2015 Sauvignon (Collio)
# 126624    Conti Formentini 2014 Caligo Sauvignon (Collio)
# 126629  Caldaro 2014 Castel Giovanelli Sauvignon (Alto...
# 126633      Cantina Cortaccia 2014 Sauvignon (Alto Adige)
# 127693        St. Pauls 2013 Gfill Sauvignon (Alto Adige)
# 127983  Poggiobello 2014 Sauvignon (Friuli Colli Orien...
#
#                                               description
# 650     You'll find aromas of tomato leaf, passion fru...
# 1292    This vibrant wine opens with varietal aromas o...
# 1399    Varietal scents of cut grass, grapefruit and a...
# 1403    This lively white opens with aromas of grapefr...
# 1408    This linear wine opens with aromas that sugges...
# 2725    Aromas suggesting honeydew melon, exotic fruit...
# 3905    Grapefruit, mineral and freshly cut grass arom...
# 3911    Delicate varietal aromas of tomato vine, cut g...
# 6259    Made with Sauvignon cultivated in high mountai...
# 6885    Aromas of pineapple, peach and a touch of vani...
# 6887    This straightforward white opens offers aromas...
# 6893    Varietal aromas of tomato vine, elderflower, g...
# 6906    Delicate aromas of tomato vine, freshly cut gr...
# 6936    Classic Sauvignon aromas of cut grass, straw, ...
# 9042    An alluring fragrance of honeysuckle comes alo...
# 11725   Polished and crisp, this opens with aromas of ...
# 12116   Savory and bright, this has classic varietal a...
# 12387   Subtle aromas include fresh hay, exotic fruit ...
# 12641   Bright, round and delicious, this has exotic f...
# 12735   Heady aromas of passion fruit and herb leap fr...
# 14373   This opens with aromas of bread crust, citrus ...
# 14778   Bright and structured, this savory wine opens ...
# 14793   This elegant white opens with aromas of crushe...
# 14883   Delicate varietal aromas including elderflower...
# 16163   Elegant and finely structured, this creamy fra...
# 16722   Grapefruit, crushed tomato vine, exotic fruit ...
# 17323   Structured but polished, this vibrant wine has...
# 17657   Subtle and sophisticated, this opens with a fl...
# 18401   Exuberant aromas suggest tropical fruit and to...
# 19315   It boasts classic varietal aromas of crushed t...
# ...                                                   ...
# 103025  Shy when first opened, this wine reveals grape...
# 103046  Fragrances suggest hay, crushed tomato vine an...
# 103443  Classic varietal scents of gooseberry, tomato ...
# 103448  This is bright and crisp, with aromas of hay, ...
# 103461  This fragrant white opens with aromas suggesti...
# 103472  Cut grass, tomato vine and gooseberry aromas a...
# 110359  Aromas of tropical fruit, French oak, hay and ...
# 110560  Here's a crisp and refreshing Sauvingon that o...
# 110915  Classic varietal aromas of hay, tomato vine an...
# 111230  Elegantly structured, it starts with aromas of...
# 112944  This has subdued scents suggesting grapefruit,...
# 116080  Aromas of exotic fruit, green melon and crushe...
# 118098  Tomato vine, cut grass, crushed stone and grap...
# 118130  This has aromas of toast and exotic fruit that...
# 118326  A structured but polished Sauvignon made from ...
# 119100  Aromas of candied citrus and bell pepper lead ...
# 119494  Matured on its lees for eight months in barriq...
# 120464  Subtle aromas of tomato vine, chopped herb and...
# 120475  Cut grass, tomato vine and gooseberry aromas l...
# 120841  Heady exotic fruit, tomato vine and chopped he...
# 121998  Intense aromas of tomato vine, chopped mint, b...
# 122001  Intense aromas of tomato leaf, hay and honeyde...
# 123001  This pleasant Sauvignon from Friuli shows typi...
# 124865  This opens with subtle aromas suggesting white...
# 124878  Here's a big round white that opens with aroma...
# 126624  Alluring scents of hay, white flower, stone fr...
# 126629  Aromas of tomato vine, hay and passion fruit u...
# 126633  This refined white opens with delicate aromas ...
# 127693  It shows the classic aromas of Alto Adige Sauv...
# 127983  This offers subdued aromas of elderflower, sag...
#
# [165 rows x 2 columns]

# %% [markdown]
# Googling some of these bottles showed that they are indeed Sauvignon Blanc.

# %%
df['varietal'] = df['varietal'].map(lambda x: 'Sauvignon Blanc' if x == 'Sauvignon' else x)
df['varietal'] = df['varietal'].map(lambda x: 'Shiraz' if x == 'Syrah' else x)

# %% [markdown]
# The average (mean) province contributes about 300 wines to the list. But obviously some provinces dominate.

# %%
df['title'].value_counts().hist(bins=20, log=True)

# %% [markdown]
# Most wines appear only once, but seems like a few appears multiple times

# %%
df.groupby(by='country')['designation'].value_counts().nlargest(20)
# Out:
# country    designation
# US         Reserve            1388
#            Estate             1119
# Italy      Riserva             639
# US         Estate Grown        549
# Chile      Reserva             492
# France     Barrel sample       367
# Spain      Crianza             312
# US         Dry                 300
# France     Vieilles Vignes     279
#            Barrel Sample       251
# Spain      Reserva             249
# US         Estate Bottled      233
# Portugal   Reserva             212
# Argentina  Reserva             207
# France     Tradition           197
# Italy      Brut                171
# US         Old Vine            171
# Italy      Extra Dry           166
# US         Rosé of             158
# France     Brut Rosé           150
# Name: designation, dtype: int64

# %% [markdown]
# The designation doesn't seem to be anything regulated

# %%
df['country_varietal'] = df['country']+ ' ' +df['varietal']

# %%
top_grape = df['varietal'].value_counts().nlargest(50).to_frame('count').reset_index()
top_grape.rename(columns={'index':'varietal'}, inplace=True)
top_grape
# Out:
#                          varietal  count
# 0                      Pinot Noir  12278
# 1                      Chardonnay  10868
# 2              Cabernet Sauvignon   8840
# 3                       Red Blend   8243
# 4        Bordeaux-style Red Blend   6471
# 5                 Sauvignon Blanc   4857
# 6                        Riesling   4773
# 7                          Shiraz   4618
# 8                            Rosé   3220
# 9                          Merlot   2896
# 10                       Nebbiolo   2607
# 11                      Zinfandel   2530
# 12                     Sangiovese   2462
# 13                         Malbec   2446
# 14                 Portuguese Red   2282
# 15                    White Blend   2179
# 16                Sparkling Blend   1971
# 17                    Tempranillo   1671
# 18          Rhône-style Red Blend   1343
# 19                     Pinot Gris   1324
# 20                Champagne Blend   1308
# 21                 Cabernet Franc   1243
# 22               Grüner Veltliner   1201
# 23               Portuguese White   1057
# 24     Bordeaux-style White Blend    993
# 25                   Pinot Grigio    980
# 26                 Gewürztraminer    940
# 27                          Gamay    926
# 28                       Viognier    922
# 29                   Petite Sirah    702
# 30              Sangiovese Grosso    696
# 31                          Glera    646
# 32                        Barbera    644
# 33                           Port    628
# 34                       Grenache    607
# 35  Corvina, Rondinella, Molinara    574
# 36              Tempranillo Blend    553
# 37                   Chenin Blanc    546
# 38                      Carmenère    533
# 39                       Albariño    434
# 40        Rhône-style White Blend    395
# 41                    Pinot Blanc    395
# 42                      Aglianico    339
# 43                        Moscato    330
# 44                   Nero d'Avola    324
# 45                       Garnacha    308
# 46                        Verdejo    266
# 47                          Melon    256
# 48                   Petit Verdot    254
# 49                      Garganega    247

# %%
top_grape_country = df['country_varietal'].value_counts().nlargest(75).to_frame('count').reset_index()
top_grape_country.rename(columns={'index':'country_varietal'}, inplace=True)

# %%
for i in range(5):
    print(df['description'][i])
    print('\n')
# Out:
# Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity.
#
#
# This is ripe and fruity, a wine that is smooth while still structured. Firm tannins are filled out with juicy red berry fruits and freshened with acidity. It's  already drinkable, although it will certainly be better from 2016.
#
#
# Tart and snappy, the flavors of lime flesh and rind dominate. Some green pineapple pokes through, with crisp acidity underscoring the flavors. The wine was all stainless-steel fermented.
#
#
# Pineapple rind, lemon pith and orange blossom start off the aromas. The palate is a bit more opulent, with notes of honey-drizzled guava and mango giving way to a slightly astringent, semidry finish.
#
#
# Much like the regular bottling from 2012, this comes across as rather rough and tannic, with rustic, earthy, herbal characteristics. Nonetheless, if you think of it as a pleasantly unfussy country wine, it's a good companion to a hearty winter stew.

# %%
country_df = df.groupby(by='country').agg({'points':'median','price':'median','description':'; '.join}).reset_index()
varietal_df = df.groupby(by='varietal').agg({'points':'median','price':'median','description':'; '.join}).reset_index()
country_varietal_df = df.groupby(by=['country','varietal']).agg({'points':'median','price':'median','description':'; '.join}).reset_index()
country_varietal_df.head()
# Out:
#      country                    varietal  points  price  \
# 0  Argentina                     Barbera    85.0   18.0
# 1  Argentina                     Bonarda    87.0   15.0
# 2  Argentina    Bordeaux-style Red Blend    91.0   37.0
# 3  Argentina  Bordeaux-style White Blend    83.0   14.0
# 4  Argentina              Cabernet Blend    88.0   30.0
#
#                                          description
# 0  This smells roasted, leathery and earthy, with...
# 1  Meaty and rubbery, but that's young Bonarda. T...
# 2  Flat in color, with a dull luster, this smells...
# 3  Bland and chunky, with aromas of talcum powder...
# 4  This blend of 88% Cabernet Sauvignon and 12% C...

# %%
# obtain grape name tokens for later removal from description
grape_names = df['varietal'].fillna('').unique().tolist()
grape_tokens = []
for name in grape_names:
    name = name.lower()
    tokens = re.split('[- ]', name)
    grape_tokens += tokens

# %%
wine_remove_words = ['wine','rosé', 'red', 'white', 'drink', 'aroma', 'flavor','vineyard']
other_remove_words = ['\'s', "'"]

# %%
post_lem_remove = set(wine_remove_words + other_remove_words)
pre_lem_remove = set([p for p in string.punctuation] + nltk.corpus.stopwords.words('english') + grape_tokens)
#use set to improve performance

def clean_tokenizer(text):
    """Turn long text into lowercase tokens, remove punctuations & stopwords
    e.g: fro"""
    tokens = nltk.tokenize.word_tokenize(text.lower())
    lemmatizer = WordNetLemmatizer()
    
    clean_tokens = [lemmatizer.lemmatize(t) for t in tokens if not 
                    ((t in pre_lem_remove) or (lemmatizer.lemmatize(t) in post_lem_remove) or (t.isnumeric()))]
    
    return clean_tokens

tfidf = TfidfVectorizer(lowercase=False, tokenizer=clean_tokenizer, token_pattern=None,
                        stop_words=None, max_df=0.7, min_df=10, ngram_range=(1,3))
# discarding terms that occur > 70% of the time & < 10 times. Using both normal & bigrams
tfidf_2 = TfidfVectorizer(lowercase=False, tokenizer=clean_tokenizer, token_pattern=None,
                        stop_words=None, max_df=0.7, min_df=10, ngram_range=(1,3))

# %%
tfidf_matrix = tfidf.fit_transform(varietal_df['description'])

# %%
tfidf_matrix_2 = tfidf_2.fit_transform(country_varietal_df['description'])

# %%
tfidf_matrix.shape
# Out:
# (705, 29768)

# %%
tfidf_matrix_2.shape
# Out:
# (1592, 34303)

# %%
def top_tfidf_feats(tfidf_row, features, n_feats=25):
    ''' Get top n tfidf values in row and return them with their corresponding feature names.'''
    top_ids = np.argsort(tfidf_row)[::-1][:n_feats]
    # sort features in row (by tfidf score) -> ascending
    # then reverse to get descending, then slice top n
    
    top_features = [(features[i], tfidf_row[i]) for i in top_ids]
    df = pd.DataFrame(top_features) # return as a Dataframe
    df.columns = ['feature', 'tfidf']
    return df

def top_feats_in_doc(tfidf_matrix, features, row_id, n_feats=25):
    ''' Top tfidf features in specific document (matrix row)
    Gotta call this instead of top_tf_idf_feats because tfidf
    is sparse matrix -> does not support all matrix operations.
    '''
    # first convert a row to full matrix format
    row = np.squeeze(tfidf_matrix[row_id].toarray())
    
    # return a df
    return top_tfidf_feats(row, features, n_feats)

# %%
features = tfidf.get_feature_names()
features_2 = tfidf_2.get_feature_names()

def look_at(varietal_name, n_feats=10):
    row = varietal_df[varietal_df['varietal']==varietal_name]
    row_id = row.index
    print(top_feats_in_doc(tfidf_matrix, features,row_id, n_feats=n_feats))

def look_at_random(n=10, n_feats=10):
    '''Look at n random wines'''
    row_ids = random.sample(range(1, 100), n)
    for row_id in row_ids:
        print('_'*10)
        print(varietal_df.iloc[row_id]['varietal'])
        print(top_feats_in_doc(tfidf_matrix, features,row_id, n_feats=n_feats))
        
def look_at_cv(country_varietal_name, n_feats=10):
    row = country_varietal_df[country_varietal_df['country_varietal']==country_varietal_name]
    row_id = row.index
    print(top_feats_in_doc(tfidf_matrix_2, features_2,row_id, n_feats=n_feats))

def look_at_random_cv(n=10, n_feats=10):
    '''Look at n random wines'''
    row_ids = random.sample(range(1, 100), n)
    for row_id in row_ids:
        print('_'*10)
        print(country_varietal_df.iloc[row_id]['country_varietal'])
        print(top_feats_in_doc(tfidf_matrix_2, features_2,row_id, n_feats=n_feats))

# %%
top_cv_names = top_grape_country['country_varietal'].tolist()
print(len(top_cv_names))
for cv in top_cv_names:
    print('_________________')
    print(cv)
    look_at_cv(cv, n_feats=10)
# Out:
# 75
# _________________
# US Pinot Noir
#       feature     tfidf
# 0      cherry  0.398882
# 1   raspberry  0.228446
# 2       fruit  0.205777
# 3        cola  0.189910
# 4         oak  0.145866
# 5   cranberry  0.145163
# 6      tannin  0.138076
# 7     acidity  0.123776
# 8        show  0.114481
# 9  strawberry  0.112584
# _________________
# US Cabernet Sauvignon
#       feature     tfidf
# 0      tannin  0.298556
# 1  blackberry  0.295478
# 2      cherry  0.249072
# 3         oak  0.214519
# 4     currant  0.212702
# 5       fruit  0.170663
# 6         cab  0.161280
# 7   chocolate  0.133238
# 8      cassis  0.127624
# 9       cedar  0.123643
# _________________
# US Chardonnay
#           feature     tfidf
# 0             oak  0.253298
# 1            pear  0.225448
# 2       pineapple  0.213367
# 3        buttered  0.199631
# 4           lemon  0.192099
# 5         acidity  0.185633
# 6  buttered toast  0.176813
# 7           fruit  0.169804
# 8         vanilla  0.146367
# 9           toast  0.145545
# _________________
# France Bordeaux-style Red Blend
#      feature     tfidf
# 0     tannin  0.366712
# 1      fruit  0.352863
# 2       ripe  0.194664
# 3       wood  0.192977
# 4    acidity  0.177197
# 5       firm  0.169074
# 6     sample  0.148325
# 7  structure  0.147704
# 8      juicy  0.141164
# 9       rich  0.133569
# _________________
# Italy Red Blend
#         feature     tfidf
# 0        cherry  0.289783
# 1        tannin  0.268342
# 2        palate  0.213525
# 3     alongside  0.187907
# 4         spice  0.165269
# 5         offer  0.157527
# 6         berry  0.142635
# 7  palate offer  0.140939
# 8        pepper  0.138552
# 9          open  0.130140
# _________________
# US Shiraz
#       feature     tfidf
# 0  blackberry  0.265226
# 1       fruit  0.255588
# 2      pepper  0.221186
# 3      tannin  0.185614
# 4      cherry  0.178080
# 5        meat  0.139093
# 6        show  0.136694
# 7        dark  0.128900
# 8      palate  0.115121
# 9        rich  0.110465
# _________________
# US Red Blend
#       feature     tfidf
# 0      cherry  0.300541
# 1      tannin  0.259290
# 2       fruit  0.227565
# 3  blackberry  0.206547
# 4   chocolate  0.144463
# 5        dark  0.135678
# 6       spice  0.118046
# 7        herb  0.115507
# 8      tannic  0.114691
# 9      palate  0.114287
# _________________
# France Chardonnay
#         feature     tfidf
# 0         fruit  0.270909
# 1       acidity  0.266480
# 2          ripe  0.233022
# 3       texture  0.192585
# 4  yellow fruit  0.189538
# 5         crisp  0.183244
# 6     character  0.163265
# 7          wood  0.162610
# 8        yellow  0.159402
# 9          rich  0.157661
# _________________
# Italy Nebbiolo
#      feature     tfidf
# 0     tannin  0.283614
# 1     cherry  0.258113
# 2      berry  0.199928
# 3     palate  0.186285
# 4   licorice  0.158014
# 5      spice  0.148112
# 6  alongside  0.147990
# 7       firm  0.137617
# 8    leather  0.130996
# 9      offer  0.121416
# _________________
# US Zinfandel
#       feature     tfidf
# 0         zin  0.505981
# 1  blackberry  0.235278
# 2      cherry  0.176921
# 3      tannin  0.172556
# 4     alcohol  0.141376
# 5      pepper  0.140904
# 6       fruit  0.138229
# 7   raspberry  0.124909
# 8         dry  0.124341
# 9       berry  0.119953
# _________________
# Portugal Portuguese Red
#      feature     tfidf
# 0     tannin  0.355949
# 1      fruit  0.333960
# 2       ripe  0.198801
# 3    acidity  0.190927
# 4       rich  0.177172
# 5      aging  0.172105
# 6       wood  0.151776
# 7      douro  0.146106
# 8  structure  0.138809
# 9      juicy  0.138805
# _________________
# US Merlot
#       feature     tfidf
# 0      cherry  0.377297
# 1      tannin  0.296576
# 2       fruit  0.227580
# 3         oak  0.178269
# 4  blackberry  0.149846
# 5         dry  0.138377
# 6     currant  0.135433
# 7        soft  0.129546
# 8        plum  0.126186
# 9        herb  0.123486
# _________________
# Italy Sangiovese
#         feature     tfidf
# 0        cherry  0.296784
# 1        tannin  0.260209
# 2        palate  0.200391
# 3         berry  0.179795
# 4     alongside  0.171332
# 5    underbrush  0.154565
# 6  palate offer  0.140379
# 7         offer  0.138380
# 8       leather  0.133364
# 9         spice  0.126101
# _________________
# US Sauvignon Blanc
#       feature     tfidf
# 0        lime  0.257579
# 1       lemon  0.224274
# 2     acidity  0.218897
# 3       crisp  0.184106
# 4  grapefruit  0.169094
# 5      citrus  0.168147
# 6  gooseberry  0.166557
# 7       green  0.154618
# 8         dry  0.146760
# 9       fruit  0.137616
# _________________
# France Pinot Noir
#       feature     tfidf
# 0      tannin  0.347768
# 1       fruit  0.346579
# 2     acidity  0.240328
# 3        ripe  0.187513
# 4   structure  0.179555
# 5        firm  0.150248
# 6       aging  0.141282
# 7        rich  0.140346
# 8        wood  0.129198
# 9  structured  0.123007
# _________________
# France Rosé
#       feature     tfidf
# 0     acidity  0.320054
# 1       fruit  0.280051
# 2       crisp  0.239089
# 3      fruity  0.213626
# 4        ripe  0.182684
# 5  aftertaste  0.174311
# 6       light  0.168533
# 7  strawberry  0.145638
# 8  attractive  0.145062
# 9       fresh  0.137676
# _________________
# US Bordeaux-style Red Blend
#           feature     tfidf
# 0          tannin  0.283191
# 1          cherry  0.278206
# 2           fruit  0.214389
# 3      blackberry  0.207166
# 4            herb  0.183119
# 5  bordeaux-style  0.181441
# 6             oak  0.153999
# 7         currant  0.148034
# 8            dark  0.129600
# 9       chocolate  0.125519
# _________________
# Germany Riesling
#      feature     tfidf
# 0      peach  0.223927
# 1  tangerine  0.200198
# 2    acidity  0.194077
# 3    mineral  0.191912
# 4     palate  0.176738
# 5       lime  0.173907
# 6        yet  0.160758
# 7        dry  0.157482
# 8       note  0.154571
# 9      honey  0.150203
# _________________
# US Riesling
#    feature     tfidf
# 0      dry  0.252471
# 1    peach  0.225604
# 2     lime  0.205198
# 3  off-dry  0.196610
# 4  acidity  0.182134
# 5    lemon  0.181662
# 6   palate  0.154879
# 7     note  0.152555
# 8     pear  0.143862
# 9    sweet  0.140596
# _________________
# Argentina Malbec
#       feature     tfidf
# 0       berry  0.358371
# 1  blackberry  0.254563
# 2        plum  0.228507
# 3      palate  0.211002
# 4        feel  0.190714
# 5      herbal  0.172561
# 6         oak  0.163009
# 7        note  0.142263
# 8       fruit  0.141432
# 9   chocolate  0.115131
# _________________
# Spain Tempranillo
#       feature     tfidf
# 0       berry  0.351170
# 1        plum  0.273301
# 2        feel  0.197950
# 3         oak  0.185690
# 4      palate  0.180117
# 5       rioja  0.169319
# 6  blackberry  0.160863
# 7       fruit  0.142922
# 8      cherry  0.141820
# 9      tannic  0.137245
# _________________
# France Champagne Blend
#      feature     tfidf
# 0    acidity  0.253422
# 1      crisp  0.230253
# 2      fruit  0.225569
# 3       ripe  0.203907
# 4      ready  0.177454
# 5    texture  0.169045
# 6        age  0.159048
# 7  character  0.151826
# 8       rich  0.148918
# 9       soft  0.143671
# _________________
# Austria Grüner Veltliner
#      feature     tfidf
# 0       pear  0.332114
# 1   screwcap  0.212291
# 2     palate  0.211252
# 3  freshness  0.171817
# 4      green  0.171700
# 5      fresh  0.166175
# 6      fruit  0.161606
# 7       ripe  0.158369
# 8     pepper  0.148295
# 9       nose  0.143399
# _________________
# Portugal Portuguese White
#        feature     tfidf
# 0      acidity  0.259615
# 1        crisp  0.239566
# 2        fruit  0.203528
# 3       fruity  0.197287
# 4         ripe  0.193465
# 5      texture  0.174767
# 6        ready  0.171677
# 7        vinho  0.167663
# 8        verde  0.166066
# 9  vinho verde  0.166066
# _________________
# France Bordeaux-style White Blend
#       feature     tfidf
# 0     acidity  0.256834
# 1       fruit  0.236058
# 2        ripe  0.200392
# 3    botrytis  0.198361
# 4   character  0.192616
# 5       crisp  0.191995
# 6  herbaceous  0.160539
# 7     texture  0.158508
# 8        rich  0.154824
# 9      sample  0.153252
# _________________
# US Cabernet Franc
#   feature     tfidf
# 0  cherry  0.385598
# 1  tannin  0.302514
# 2    herb  0.184594
# 3     cab  0.181249
# 4   fruit  0.160915
# 5  palate  0.154973
# 6    note  0.134563
# 7     oak  0.122648
# 8   spice  0.116722
# 9    ripe  0.111427
# _________________
# France Gamay
#       feature     tfidf
# 0      tannin  0.321311
# 1       fruit  0.306698
# 2     acidity  0.253713
# 3      cherry  0.188736
# 4  beaujolais  0.184110
# 5        ripe  0.173608
# 6   structure  0.172677
# 7        firm  0.164801
# 8         cru  0.154024
# 9      fruity  0.153958
# _________________
# France Sauvignon Blanc
#       feature     tfidf
# 0       fruit  0.240371
# 1     acidity  0.218397
# 2       crisp  0.217442
# 3        ripe  0.205468
# 4     texture  0.198850
# 5   character  0.171375
# 6       ready  0.167531
# 7      citrus  0.156760
# 8        rich  0.142152
# 9  herbaceous  0.141601
# _________________
# US Rosé
#       feature     tfidf
# 0  strawberry  0.347620
# 1  watermelon  0.262483
# 2        pink  0.231944
# 3         dry  0.230874
# 4       color  0.217392
# 5      cherry  0.209548
# 6   raspberry  0.199969
# 7       light  0.167614
# 8        pale  0.148783
# 9     acidity  0.134467
# _________________
# US Pinot Gris
#       feature     tfidf
# 0        pear  0.397156
# 1       fruit  0.259355
# 2  pear fruit  0.151891
# 3       fresh  0.146913
# 4      citrus  0.133303
# 5     acidity  0.132205
# 6       peach  0.127230
# 7         dry  0.124164
# 8       lemon  0.122113
# 9       light  0.120876
# _________________
# Spain Red Blend
#       feature     tfidf
# 0       berry  0.331509
# 1        plum  0.289927
# 2      palate  0.190089
# 3  blackberry  0.166460
# 4      herbal  0.160027
# 5      cherry  0.152507
# 6        feel  0.151003
# 7       fruit  0.144678
# 8         oak  0.141749
# 9        note  0.137921
# _________________
# US Viognier
#        feature     tfidf
# 0        peach  0.281445
# 1        fruit  0.215186
# 2         pear  0.176927
# 3      apricot  0.162910
# 4      acidity  0.155364
# 5     tropical  0.150214
# 6  honeysuckle  0.149060
# 7        lemon  0.147595
# 8       palate  0.136188
# 9         show  0.134660
# _________________
# Italy White Blend
#        feature     tfidf
# 0        fruit  0.226169
# 1        peach  0.189252
# 2        offer  0.186520
# 3       palate  0.180170
# 4       citrus  0.170813
# 5       almond  0.170194
# 6       yellow  0.162539
# 7  stone fruit  0.161790
# 8       flower  0.157944
# 9        stone  0.157086
# _________________
# Chile Cabernet Sauvignon
#       feature     tfidf
# 0       berry  0.347876
# 1      herbal  0.312617
# 2      cassis  0.261331
# 3        plum  0.203111
# 4      palate  0.182095
# 5        feel  0.163200
# 6       fruit  0.141425
# 7  blackberry  0.135086
# 8         cab  0.130882
# 9      cherry  0.127561
# _________________
# Italy Sangiovese Grosso
#    feature     tfidf
# 0   cherry  0.256644
# 1    spice  0.218523
# 2  leather  0.189288
# 3    fruit  0.179108
# 4   bright  0.174031
# 5  tobacco  0.169184
# 6    rosso  0.165936
# 7     dark  0.161686
# 8     cola  0.146734
# 9    berry  0.140014
# _________________
# US Petite Sirah
#       feature     tfidf
# 0  blackberry  0.313260
# 1      tannin  0.300251
# 2        dark  0.184860
# 3   chocolate  0.184247
# 4      cherry  0.154817
# 5      pepper  0.154526
# 6   blueberry  0.151213
# 7      tannic  0.146856
# 8       fruit  0.141709
# 9        show  0.123403
# _________________
# France Rhône-style Red Blend
#         feature     tfidf
# 0        cherry  0.288968
# 1         fruit  0.230828
# 2        tannin  0.225457
# 3          note  0.209428
# 4      garrigue  0.152759
# 5          hint  0.147044
# 6          plum  0.136333
# 7          year  0.134944
# 8         spice  0.120161
# 9  cherry fruit  0.114808
# _________________
# France Riesling
#      feature     tfidf
# 0        dry  0.289102
# 1      lemon  0.272895
# 2  freshness  0.256062
# 3     palate  0.254554
# 4       nose  0.170845
# 5     citrus  0.152808
# 6       ripe  0.151119
# 7       note  0.147078
# 8      fruit  0.146726
# 9      fresh  0.146583
# _________________
# Italy Glera
#     feature     tfidf
# 0     peach  0.247550
# 1  sparkler  0.236887
# 2   perlage  0.204347
# 3    flower  0.203373
# 4    citrus  0.184402
# 5   acidity  0.171053
# 6    mousse  0.161792
# 7      pear  0.155801
# 8    palate  0.148128
# 9    bright  0.131790
# _________________
# Chile Sauvignon Blanc
#          feature     tfidf
# 0             sb  0.336966
# 1          green  0.326981
# 2         citrus  0.247736
# 3           lime  0.245966
# 4         palate  0.177628
# 5     grapefruit  0.171654
# 6  passion fruit  0.169451
# 7        passion  0.167893
# 8           bell  0.162975
# 9    bell pepper  0.162270
# _________________
# US Rhône-style Red Blend
#        feature     tfidf
# 0       cherry  0.240807
# 1        fruit  0.227243
# 2  rhône-style  0.177263
# 3       pepper  0.174284
# 4   blackberry  0.171923
# 5         show  0.162939
# 6    raspberry  0.155401
# 7         nose  0.151625
# 8       palate  0.151532
# 9        spice  0.140338
# _________________
# US Sparkling Blend
#       feature     tfidf
# 0      bubbly  0.331853
# 1        lime  0.204616
# 2    sparkler  0.199189
# 3  strawberry  0.194065
# 4      bubble  0.185964
# 5   raspberry  0.164214
# 6         dry  0.164117
# 7     vanilla  0.156636
# 8        made  0.149131
# 9        rich  0.143979
# _________________
# Australia Shiraz
#        feature     tfidf
# 0        fruit  0.221204
# 1         note  0.192484
# 2       tannin  0.174818
# 3      vanilla  0.173666
# 4      barossa  0.146174
# 5  full-bodied  0.143661
# 6         hint  0.143503
# 7       supple  0.142162
# 8        olive  0.139920
# 9         long  0.131878
# _________________
# US White Blend
#    feature     tfidf
# 0    peach  0.231265
# 1     pear  0.209521
# 2    fruit  0.187041
# 3  acidity  0.171244
# 4    sweet  0.166668
# 5      dry  0.153050
# 6   citrus  0.152609
# 7   palate  0.144099
# 8    crisp  0.143099
# 9  apricot  0.133364
# _________________
# Italy Corvina, Rondinella, Molinara
#      feature     tfidf
# 0    amarone  0.399341
# 1     cherry  0.240144
# 2      spice  0.225404
# 3      fruit  0.188132
# 4    tobacco  0.140916
# 5       cola  0.137716
# 6    leather  0.123503
# 7       dark  0.122376
# 8  intensity  0.121931
# 9      berry  0.117329
# _________________
# Portugal Port
#      feature     tfidf
# 0      fruit  0.298923
# 1    acidity  0.229437
# 2     tannin  0.215877
# 3      tawny  0.197546
# 4  character  0.190594
# 5       ripe  0.182566
# 6      aging  0.182481
# 7       rich  0.178950
# 8       wood  0.167477
# 9        dry  0.155175
# _________________
# Italy Pinot Grigio
#    feature     tfidf
# 0     pear  0.227466
# 1   citrus  0.213327
# 2    peach  0.213240
# 3  acidity  0.176595
# 4    offer  0.175774
# 5    fruit  0.170688
# 6   palate  0.154592
# 7   flower  0.143518
# 8    crisp  0.141232
# 9    fresh  0.139109
# _________________
# Austria Riesling
#      feature     tfidf
# 0      lemon  0.253984
# 1  freshness  0.208055
# 2     palate  0.200069
# 3      fruit  0.198274
# 4     citrus  0.178519
# 5       ripe  0.167012
# 6    slender  0.162359
# 7   screwcap  0.155508
# 8       nose  0.145094
# 9      fresh  0.139142
# _________________
# Spain Tempranillo Blend
#   feature     tfidf
# 0   berry  0.316283
# 1    plum  0.281168
# 2   rioja  0.229465
# 3     oak  0.169249
# 4  palate  0.168601
# 5    feel  0.158948
# 6  earthy  0.156500
# 7   fruit  0.146656
# 8  cherry  0.130468
# 9   baked  0.125677
# _________________
# Argentina Cabernet Sauvignon
#       feature     tfidf
# 0       berry  0.353616
# 1      herbal  0.285354
# 2        plum  0.223249
# 3        feel  0.197115
# 4      palate  0.189233
# 5      cassis  0.185550
# 6       fruit  0.126688
# 7      cherry  0.126424
# 8  blackberry  0.124973
# 9         oak  0.124204
# _________________
# New Zealand Sauvignon Blanc
#          feature     tfidf
# 0     grapefruit  0.263740
# 1          fruit  0.203739
# 2           note  0.198886
# 3  passion fruit  0.198218
# 4        passion  0.196395
# 5  medium-bodied  0.162587
# 6         herbal  0.151770
# 7         citrus  0.143636
# 8          green  0.141117
# 9           hint  0.140777
# _________________
# Chile Carmenère
#       feature     tfidf
# 0      herbal  0.420512
# 1       berry  0.306579
# 2        plum  0.232516
# 3       olive  0.198197
# 4      palate  0.182815
# 5        feel  0.171989
# 6         oak  0.160212
# 7        herb  0.152044
# 8       fruit  0.149219
# 9  blackberry  0.148614
# _________________
# US Grenache
#       feature     tfidf
# 0      cherry  0.323315
# 1   raspberry  0.182731
# 2    bottling  0.165537
# 3       light  0.164396
# 4       fruit  0.163526
# 5        show  0.163453
# 6      palate  0.163442
# 7  strawberry  0.161002
# 8        nose  0.138105
# 9        plum  0.123324
# _________________
# US Malbec
#       feature     tfidf
# 0       fruit  0.269154
# 1      tannin  0.219772
# 2        plum  0.197828
# 3        dark  0.185518
# 4      cherry  0.170410
# 5        herb  0.167162
# 6  blackberry  0.165657
# 7       spice  0.161570
# 8         oak  0.147797
# 9      barrel  0.122847
# _________________
# Chile Chardonnay
#     feature     tfidf
# 0       oak  0.236481
# 1    palate  0.211610
# 2      feel  0.200548
# 3    resiny  0.199948
# 4  tropical  0.198441
# 5     fruit  0.177482
# 6    citrus  0.170650
# 7      pear  0.160849
# 8    banana  0.153960
# 9     peach  0.137586
# _________________
# New Zealand Pinot Noir
#          feature     tfidf
# 0         cherry  0.389874
# 1          fruit  0.227353
# 2   cherry fruit  0.225225
# 3           note  0.199058
# 4          silky  0.179377
# 5         tannin  0.158699
# 6           hint  0.148985
# 7         supple  0.147668
# 8  medium-bodied  0.123474
# 9           year  0.123209
# _________________
# Spain Sparkling Blend
#   feature     tfidf
# 0    cava  0.430727
# 1  yeasty  0.232228
# 2  palate  0.212540
# 3   briny  0.203023
# 4  citrus  0.183471
# 5    feel  0.181662
# 6    brut  0.166630
# 7  bready  0.148604
# 8    lime  0.143249
# 9     dry  0.141443
# _________________
# France Gewürztraminer
#         feature     tfidf
# 0         peach  0.231433
# 1        palate  0.205202
# 2          rich  0.204575
# 3         fruit  0.191078
# 4          ripe  0.175160
# 5        lychee  0.168178
# 6     sweetness  0.165977
# 7         spice  0.160958
# 8     freshness  0.160169
# 9  medium-sweet  0.156613
# _________________
# Italy Barbera
#       feature     tfidf
# 0      cherry  0.246854
# 1      palate  0.183144
# 2       spice  0.183069
# 3       berry  0.180340
# 4      tannin  0.172606
# 5   alongside  0.167538
# 6     acidity  0.157532
# 7       fruit  0.156366
# 8  blackberry  0.144052
# 9       offer  0.131913
# _________________
# France Pinot Gris
#       feature     tfidf
# 0        pear  0.419384
# 1        ripe  0.206486
# 2       fruit  0.206040
# 3      palate  0.194913
# 4   freshness  0.190258
# 5         dry  0.179676
# 6        note  0.152608
# 7  pear fruit  0.144133
# 8   ripe pear  0.141841
# 9        nose  0.138626
# _________________
# France Malbec
#     feature     tfidf
# 0    tannin  0.348300
# 1     fruit  0.332739
# 2    cahors  0.182284
# 3      wood  0.179080
# 4     dense  0.169634
# 5     aging  0.164523
# 6  powerful  0.143626
# 7   acidity  0.143476
# 8      dark  0.139022
# 9      firm  0.136004
# _________________
# US Sangiovese
#       feature     tfidf
# 0      cherry  0.368197
# 1      tannin  0.218191
# 2   cranberry  0.175447
# 3       fruit  0.168414
# 4       light  0.168039
# 5  strawberry  0.146784
# 6         dry  0.141450
# 7        tart  0.139227
# 8   raspberry  0.123896
# 9        show  0.120856
# _________________
# Chile Red Blend
#       feature     tfidf
# 0       berry  0.346646
# 1      herbal  0.304893
# 2      cassis  0.192693
# 3        plum  0.192189
# 4      palate  0.180651
# 5       olive  0.173989
# 6  blackberry  0.151252
# 7       spice  0.141823
# 8        feel  0.131570
# 9       fruit  0.128591
# _________________
# Australia Chardonnay
#          feature     tfidf
# 0      pineapple  0.272633
# 1          peach  0.234416
# 2         citrus  0.221417
# 3          fruit  0.210855
# 4           note  0.197042
# 5          chard  0.164621
# 6           pear  0.158846
# 7  medium-bodied  0.141493
# 8        citrusy  0.138031
# 9         palate  0.119010
# _________________
# US Gewürztraminer
#       feature     tfidf
# 0      lychee  0.302590
# 1         dry  0.223074
# 2        rose  0.194022
# 3     acidity  0.169657
# 4     off-dry  0.166276
# 5       spice  0.154066
# 6  rose petal  0.147811
# 7      floral  0.145094
# 8       petal  0.141707
# 9       peach  0.136181
# _________________
# France Sparkling Blend
#   feature     tfidf
# 0  mousse  0.279004
# 1     dry  0.226824
# 2   fresh  0.225749
# 3  palate  0.190964
# 4    fizz  0.173412
# 5  creamy  0.170887
# 6  frothy  0.169844
# 7   fruit  0.158824
# 8   light  0.157039
# 9  fruity  0.157014
# _________________
# Chile Pinot Noir
#      feature     tfidf
# 0       plum  0.351899
# 1     cherry  0.243852
# 2  raspberry  0.236314
# 3        oak  0.193257
# 4     palate  0.176565
# 5     herbal  0.172475
# 6      berry  0.170558
# 7       feel  0.169758
# 8       note  0.128213
# 9      spicy  0.125334
# _________________
# US Pinot Grigio
#    feature     tfidf
# 0    crisp  0.234613
# 1  acidity  0.203738
# 2     pear  0.195995
# 3      dry  0.194217
# 4   citrus  0.181568
# 5     lime  0.171926
# 6    light  0.155546
# 7    lemon  0.154070
# 8    peach  0.151379
# 9     like  0.143540
# _________________
# Italy Sparkling Blend
#        feature     tfidf
# 0      perlage  0.282024
# 1        bread  0.278833
# 2  bread crust  0.224862
# 3     sparkler  0.189774
# 4        crust  0.188883
# 5      toasted  0.161416
# 6       palate  0.160604
# 7    alongside  0.156108
# 8        offer  0.148386
# 9       citrus  0.140315
# _________________
# Italy Aglianico
#       feature     tfidf
# 0      tannin  0.272525
# 1      cherry  0.218889
# 2       spice  0.189051
# 3      palate  0.156562
# 4     leather  0.148805
# 5    licorice  0.147192
# 6  blackberry  0.146584
# 7     tobacco  0.142055
# 8       fruit  0.132937
# 9        firm  0.128032
# _________________
# Italy Nero d'Avola
#       feature     tfidf
# 0      cherry  0.252223
# 1  blackberry  0.208394
# 2      tannin  0.197569
# 3      palate  0.165858
# 4       offer  0.165258
# 5       berry  0.159553
# 6       spice  0.157204
# 7   alongside  0.142932
# 8        open  0.138384
# 9      almond  0.134823
# _________________
# US Tempranillo
#    feature     tfidf
# 0    fruit  0.273136
# 1   tannin  0.267671
# 2   cherry  0.242832
# 3      oak  0.174279
# 4  tobacco  0.160009
# 5    light  0.130087
# 6     dark  0.126659
# 7    spice  0.124368
# 8     note  0.109046
# 9   coffee  0.096465
# _________________
# Italy Sauvignon Blanc
#         feature     tfidf
# 0   tomato vine  0.306025
# 1        tomato  0.260163
# 2         fruit  0.198515
# 3    grapefruit  0.190574
# 4  exotic fruit  0.174389
# 5          vine  0.165459
# 6         peach  0.159568
# 7        palate  0.158942
# 8       mineral  0.153232
# 9       acidity  0.143409
# _________________
# Italy Chardonnay
#    feature     tfidf
# 0   creamy  0.204713
# 1   yellow  0.191102
# 2   almond  0.186585
# 3    fruit  0.182343
# 4   citrus  0.178344
# 5    peach  0.161317
# 6   palate  0.144292
# 7    offer  0.142911
# 8   golden  0.140477
# 9  vanilla  0.134244
# _________________
# Spain Albariño
#      feature     tfidf
# 0     citrus  0.265418
# 1      peach  0.237927
# 2     palate  0.220997
# 3  nectarine  0.214867
# 4       feel  0.209402
# 5      pithy  0.183172
# 6      leesy  0.170748
# 7  minerally  0.142576
# 8     citric  0.138202
# 9      fresh  0.135152

# %%
# the next 2 lines are a repeat of a previous cell
top_grape = df['varietal'].value_counts().nlargest(57).to_frame('count').reset_index()
top_grape.rename(columns={'index':'varietal'}, inplace=True)

top_grape_names = top_grape['varietal'].tolist()
top_grape_names = [grape for grape in top_grape_names if grape not in 
                   ["Red Blend","White Blend","Sparkling Blend","Portuguese Red","Portuguese White", "Port", "Rosé"]]
print(len(top_grape_names))
for grape in top_grape_names[:10]:
    print('_________________')
    print(grape)
    look_at(grape, n_feats=10)
# Out:
# 50
# _________________
# Pinot Noir
#       feature     tfidf
# 0      cherry  0.416591
# 1   raspberry  0.216906
# 2      tannin  0.206269
# 3        cola  0.164828
# 4     acidity  0.155456
# 5         oak  0.139267
# 6   cranberry  0.127962
# 7  strawberry  0.117904
# 8       spice  0.112393
# 9        ripe  0.111617
# _________________
# Chardonnay
#      feature     tfidf
# 0    acidity  0.236186
# 1        oak  0.213559
# 2       pear  0.212767
# 3  pineapple  0.185041
# 4      lemon  0.173728
# 5       ripe  0.166243
# 6      peach  0.154875
# 7      toast  0.152705
# 8       rich  0.144073
# 9      crisp  0.140029
# _________________
# Cabernet Sauvignon
#       feature     tfidf
# 0      tannin  0.303268
# 1  blackberry  0.287101
# 2      cherry  0.266160
# 3         oak  0.208596
# 4     currant  0.193448
# 5         cab  0.183087
# 6      cassis  0.182620
# 7   chocolate  0.139473
# 8        plum  0.115001
# 9       cedar  0.112650
# _________________
# Bordeaux-style Red Blend
#       feature     tfidf
# 0      tannin  0.423229
# 1        ripe  0.190984
# 2        wood  0.168071
# 3     acidity  0.167650
# 4        firm  0.165881
# 5   structure  0.144247
# 6        rich  0.143215
# 7  blackberry  0.143064
# 8     currant  0.138641
# 9       juicy  0.128594
# _________________
# Sauvignon Blanc
#       feature     tfidf
# 0      citrus  0.242288
# 1       green  0.239794
# 2  grapefruit  0.226508
# 3        lime  0.219164
# 4     acidity  0.210949
# 5       crisp  0.180516
# 6       lemon  0.161477
# 7  gooseberry  0.160092
# 8    tropical  0.125608
# 9        note  0.124834
# _________________
# Riesling
#      feature     tfidf
# 0        dry  0.237667
# 1      lemon  0.224118
# 2      peach  0.210536
# 3    acidity  0.192699
# 4       lime  0.182289
# 5       note  0.180365
# 6     citrus  0.148056
# 7  tangerine  0.146337
# 8    off-dry  0.140102
# 9    mineral  0.133957
# _________________
# Shiraz
#       feature     tfidf
# 0  blackberry  0.266530
# 1      tannin  0.217946
# 2      pepper  0.214268
# 3      cherry  0.202338
# 4        note  0.151131
# 5        dark  0.139052
# 6        meat  0.135459
# 7       berry  0.131502
# 8       spice  0.128815
# 9        plum  0.126536
# _________________
# Merlot
#       feature     tfidf
# 0      cherry  0.389490
# 1      tannin  0.307662
# 2        plum  0.188563
# 3         oak  0.179301
# 4  blackberry  0.162164
# 5       berry  0.136836
# 6       spice  0.129946
# 7   chocolate  0.128248
# 8         dry  0.126140
# 9        soft  0.125786
# _________________
# Nebbiolo
#      feature     tfidf
# 0     tannin  0.306223
# 1     cherry  0.288068
# 2      berry  0.212877
# 3   licorice  0.166156
# 4      spice  0.151555
# 5  alongside  0.143585
# 6    leather  0.138642
# 7       firm  0.136780
# 8      offer  0.124118
# 9       note  0.118318
# _________________
# Zinfandel
#       feature     tfidf
# 0         zin  0.492298
# 1  blackberry  0.248560
# 2      cherry  0.192302
# 3      tannin  0.183673
# 4      pepper  0.148476
# 5     alcohol  0.140950
# 6   raspberry  0.132392
# 7       berry  0.127431
# 8         dry  0.127378
# 9       sweet  0.121222

# %%
look_at_random(n=10, n_feats=10)
# Out:
# __________
# Boğazkere
#                  feature     tfidf
# 0                 tannin  0.232962
# 1         nice interplay  0.218312
# 2              interplay  0.169358
# 3                 cassis  0.169343
# 4  tannin bright acidity  0.167008
# 5                 cherry  0.161025
# 6          tannin bright  0.155999
# 7                   nice  0.149793
# 8      blackberry cassis  0.143832
# 9                  flint  0.139442
# __________
# Bordeaux-style White Blend
#       feature     tfidf
# 0     acidity  0.264309
# 1        ripe  0.205404
# 2    botrytis  0.204276
# 3   character  0.196311
# 4       crisp  0.191393
# 5     texture  0.163261
# 6        rich  0.162712
# 7  herbaceous  0.162480
# 8      sample  0.155407
# 9      citrus  0.147350
# __________
# Cabernet Sauvignon-Merlot-Shiraz
#                  feature     tfidf
# 0        perfect grilled  0.176670
# 1        finish now–2012  0.176670
# 2  lingering long finish  0.173692
# 3         spice espresso  0.170952
# 4    medium-weight mouth  0.170952
# 5                entrées  0.168416
# 6           meaty savory  0.161770
# 7             mouth firm  0.159814
# 8       tannin providing  0.159814
# 9             add nuance  0.157963
# __________
# Baga
#       feature     tfidf
# 0      tannin  0.277081
# 1        rich  0.191754
# 2       grape  0.170942
# 3     acidity  0.169558
# 4     typical  0.138208
# 5       aging  0.136703
# 6   character  0.127809
# 7        dark  0.103339
# 8  structured  0.100632
# 9       ready  0.099714
# __________
# Asprinio
#                feature     tfidf
# 0        candied fruit  0.200522
# 1        offer mineral  0.162865
# 2        bright golden  0.162865
# 3  sensation alongside  0.157594
# 4          lively open  0.157594
# 5         acidity lack  0.153079
# 6               mature  0.152585
# 7       color slightly  0.149130
# 8               almond  0.145936
# 9    mineral sensation  0.145620
# __________
# Cabernet Franc-Malbec
#          feature     tfidf
# 0            cab  0.185881
# 1         earthy  0.165701
# 2     aggressive  0.161737
# 3    cherry plum  0.142727
# 4         cherry  0.138875
# 5           plum  0.137111
# 6         unveil  0.125521
# 7       nose ton  0.125521
# 8  smoky leather  0.123405
# 9   taste earthy  0.123405
# __________
# Cabernet Sauvignon-Syrah
#       feature     tfidf
# 0  blackberry  0.213670
# 1       berry  0.200989
# 2      cherry  0.165885
# 3      tannin  0.159995
# 4        note  0.130349
# 5   chocolate  0.129415
# 6      cassis  0.125249
# 7        herb  0.123031
# 8      herbal  0.120730
# 9     currant  0.119543
# __________
# Canaiolo
#                       feature     tfidf
# 0               made entirely  0.179520
# 1                    entirely  0.153087
# 2            ripe fruit prune  0.144655
# 3       dense palate delivers  0.144655
# 4            strawberry clove  0.142216
# 5                 clove fresh  0.139973
# 6  palate delivers blackberry  0.137896
# 7              entirely offer  0.137896
# 8         made entirely offer  0.137896
# 9            offer suggesting  0.134154
# __________
# Bombino Bianco
#                  feature     tfidf
# 0    made biodynamically  0.236918
# 1           bright sharp  0.232925
# 2  biodynamically farmed  0.232925
# 3     creamy consistency  0.225849
# 4             expression  0.224136
# 5             clean note  0.216938
# 6         apricot almond  0.203063
# 7         almond vanilla  0.201110
# 8         biodynamically  0.195704
# 9             note honey  0.194034
# __________
# Bordeaux-style Red Blend
#       feature     tfidf
# 0      tannin  0.423229
# 1        ripe  0.190984
# 2        wood  0.168071
# 3     acidity  0.167650
# 4        firm  0.165881
# 5   structure  0.144247
# 6        rich  0.143215
# 7  blackberry  0.143064
# 8     currant  0.138641
# 9       juicy  0.128594

# %%
top_id = varietal_df[varietal_df['varietal'].isin(top_grape_names)].index

# %%
top_id_2 = country_varietal_df[country_varietal_df['country_varietal'].isin(top_cv_names)].index

# %%
len(df.groupby(by='varietal'))
# Out:
# 705

# %%
len(df[df['varietal'].isin(top_grape_names)])/len(df)
# Out:
# 0.7424825815914925

# %% [markdown]
# Picking out the top 50 most common grapes combination out of 707 possible values still leaves us with 74% of the bottles.

# %%
top_varietal_labels = varietal_df.iloc[top_id]['varietal'].values

# %%
top_cv_labels = country_varietal_df.iloc[top_id_2]['country_varietal'].values

# %%
top_tfidf_matrix = tfidf_matrix[top_id]

# %%
top_tfidf_matrix_2 = tfidf_matrix_2[top_id_2]

# %%
linkage_matrix2 = linkage(top_tfidf_matrix_2.todense(), method='average', metric='cosine')
fig2, ax2 = plt.subplots(figsize=(15, 20)) # set size
ax2 = dendrogram(linkage_matrix2, orientation="right",
                labels=top_cv_labels)

# %%
linkage_matrix = linkage(top_tfidf_matrix.todense(), method='average', metric='cosine')
fig, ax = plt.subplots(figsize=(15, 20)) # set size
ax = dendrogram(linkage_matrix, orientation="right",
                labels=top_varietal_labels)

# %%
to_tree(linkage_matrix)
